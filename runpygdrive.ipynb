# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# gdrive	sample_data

# %%
# !ls -a
# !pwd
# !python gdrive/My\ Drive/DtUFF/teste.py
# !pwd
# !ls -a
# !python gdrive/My\ Drive/DtUFF/Dt2020/intpy/test.py
# !python
# Out:
# .  ..  .config	gdrive	.intpy	sample_data
# /content
# teste 123
# /content
# .  ..  .config	gdrive	.intpy	sample_data
# 354224848179261915075
# 0.0071370601654052734
# Python 3.6.9 (default, Jul 17 2020, 12:50:27)
# [GCC 8.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !ls -l /
# !pwd
# !ps
# !df -h
# !cat /etc/*release
# Out:
# total 96
# drwxr-xr-x   1 root root 4096 Sep 16 16:22 bin
# drwxr-xr-x   2 root root 4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root 4096 Sep 16 16:28 content
# drwxr-xr-x   1 root root 4096 Sep 18 16:44 datalab
# drwxr-xr-x   5 root root  360 Sep 24 02:51 dev
# drwxr-xr-x   1 root root 4096 Sep 24 02:51 etc
# drwxr-xr-x   2 root root 4096 Apr 24  2018 home
# drwxr-xr-x   1 root root 4096 Sep 16 16:23 lib
# drwxr-xr-x   2 root root 4096 Sep 16 16:17 lib32
# drwxr-xr-x   2 root root 4096 Aug  7 22:41 lib64
# drwxr-xr-x   2 root root 4096 Aug  7 22:39 media
# drwxr-xr-x   2 root root 4096 Aug  7 22:39 mnt
# drwxr-xr-x   1 root root 4096 Sep 16 16:24 opt
# dr-xr-xr-x 117 root root    0 Sep 24 02:51 proc
# drwx------   1 root root 4096 Sep 24 02:51 root
# drwxr-xr-x   1 root root 4096 Sep 16 16:19 run
# drwxr-xr-x   1 root root 4096 Sep 16 16:22 sbin
# drwxr-xr-x   2 root root 4096 Aug  7 22:39 srv
# drwxr-xr-x   4 root root 4096 Sep 18 16:43 swift
# ...
